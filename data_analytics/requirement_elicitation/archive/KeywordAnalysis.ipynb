# %% [markdown]
# <h3>1) Import Data</h3>

# %%
import pandas as pd
import string
import glob

path = r'data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    print(filename)
    df = pd.read_csv(filename, index_col=0, header=0)
    file_id=filename.split(".")[0].split("\\")[1]
    df["source"]=file_id
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# data\amsterdamGVB.csv
# data\amsterdamOVinfo.csv
# data\barcelonaBus.csv
# data\barcelonaTMB.csv
# data\copenhagenRejseplanen.csv
# data\dublinBus.csv
# data\dublinNextBus.csv
# data\dublinRTI.csv
# data\lisbonCarris.csv
# data\LondonMapWay.csv
# data\LondonUrbanThings.csv
# data\madridBus.csv
# data\madridJSVM.csv

# %%
df.shape
# Out:
# (7468, 6)

# %% [markdown]
# <h3>2) Remove Punctuation</h3>

# %%
reviews=[]
for review in df.review:
    reviews.append(review.translate(str.maketrans("","", string.punctuation)))
df["review"]=reviews

# %%
df.head()
# Out:
#             name  rating                date  upvotes  \
# 0  A Google user       3  September 30, 2018       20
# 1   Ozgur Kalkan       3   November 19, 2018        4
# 2      gabs igab       5    November 7, 2019        2
# 3         Damian       5       March 1, 2020        1
# 4        Pel Pan       1      March 28, 2019        1
#
#                                               review        source
# 0  Confusing for tourists with tourist tickets th...  amsterdamGVB
# 1  Its a good app more like an essential one but ...  amsterdamGVB
# 2  Excellent app I have used it on our visit to A...  amsterdamGVB
# 3  It works very well for traveling I use it ever...  amsterdamGVB
# 4   very bad accuracy and often not the shortest way  amsterdamGVB

# %%
df.shape
# Out:
# (7468, 6)

# %% [markdown]
# <h3>3) Add review length and remove short reviews</h3>

# %%
review_length=[]
for review in df.review:
    review_length.append(len(review))

# %%
df["review_length"]=pd.Series(review_length)

# %%
df=df[df.review_length>=20]

# %%
df.shape
# Out:
# (3580, 7)

# %% [markdown]
# <h3>4) Filter by good (5*) and bad (1*) experiences</h3>

# %%
df_five=df[df.rating==5]

# %%
five_length=df_five.shape[0]
five_length
# Out:
# 1534

# %%
df_one=df[df.rating==1]

# %%
one_length=df_one.shape[0]
one_length
# Out:
# 737

# %% [markdown]
# <h3>5) Extract frequently used words and calculate mentions per comment</h3>

# %%
counts_five=pd.Series(' '.join(df_five['review']).lower().split()).value_counts()

# %%
word_freq={}
for word in counts_five.index:
    word_freq[word]=[counts_five[word]/five_length,0]

# %%
counts_one=pd.Series(' '.join(df_one['review']).lower().split()).value_counts()

# %%
for word in counts_one.index:
    freq=counts_one[word]/one_length
    if word not in word_freq:
        word_freq[word]=[0,freq]
    else:
        word_freq[word][1]=freq

# %% [markdown]
# <h3>5) Insert data into Dataframe and calculate delta</h3>

# %%
mentions=pd.DataFrame.from_dict(word_freq,orient='index',columns=['good','bad'])

# %%
mentions['delta']=mentions.good-mentions.bad

# %%
sorted_mentions=mentions.sort_values(by='delta')

# %%
sorted_mentions[:50]
# Out:
#              good       bad     delta
# the      0.473272  0.947083 -0.473810
# to       0.370926  0.618725 -0.247799
# a        0.210561  0.446404 -0.235844
# it       0.307692  0.533243 -0.225551
# not      0.040417  0.234735 -0.194318
# i        0.278357  0.470828 -0.192470
# this     0.180574  0.299864 -0.119291
# is       0.202086  0.320217 -0.118131
# of       0.110169  0.225237 -0.115068
# at       0.036506  0.150611 -0.114105
# and      0.359192  0.472185 -0.112993
# no       0.035854  0.147897 -0.112043
# doesnt   0.007171  0.108548 -0.101377
# that     0.050847  0.149254 -0.098406
# bus      0.305085  0.401628 -0.096543
# was      0.018905  0.112619 -0.093714
# time     0.110821  0.203528 -0.092706
# on       0.115385  0.207598 -0.092214
# you      0.124511  0.214383 -0.089872
# times    0.041721  0.126187 -0.084466
# in       0.107562  0.181818 -0.074256
# work     0.029335  0.100407 -0.071072
# just     0.029335  0.100407 -0.071072
# useless  0.000000  0.067843 -0.067843
# update   0.016949  0.084125 -0.067176
# for      0.203390  0.270014 -0.066624
# but      0.052803  0.119403 -0.066600
# now      0.025424  0.090909 -0.065485
# are      0.041721  0.107191 -0.065470
# when     0.069752  0.134328 -0.064576
# have     0.084094  0.141113 -0.057019
# ads      0.005867  0.061058 -0.055191
# ikke     0.003911  0.058345 -0.054433
# they     0.009778  0.058345 -0.048566
# there    0.019557  0.067843 -0.048286
# as       0.048240  0.094980 -0.046740
# even     0.019557  0.065129 -0.045572
# cant     0.011734  0.056988 -0.045254
# up       0.028031  0.073270 -0.045239
# why      0.002608  0.047490 -0.044882
# crashes  0.000000  0.044776 -0.044776
# if       0.044980  0.089552 -0.044572
# all      0.050196  0.093623 -0.043427
# de       0.024772  0.067843 -0.043071
# due      0.011734  0.054274 -0.042540
# your     0.028031  0.070556 -0.042525
# buses    0.046284  0.088195 -0.041911
# do       0.015645  0.055631 -0.039986
# dont     0.027379  0.066486 -0.039106
# my       0.075619  0.113976 -0.038356

# %%
sorted_mentions[-50:]
# Out:
#                  good       bad     delta
# found        0.013690  0.005427  0.008262
# travelling   0.009778  0.001357  0.008422
# super        0.009778  0.001357  0.008422
# een          0.008475  0.000000  0.008475
# what         0.048240  0.039349  0.008891
# application  0.013038  0.004071  0.008967
# tfi          0.009778  0.000000  0.009778
# job          0.013038  0.002714  0.010324
# life         0.011734  0.001357  0.010377
# around       0.021512  0.010855  0.010658
# without      0.029987  0.018996  0.010991
# much         0.035854  0.024423  0.011431
# awesome      0.011734  0.000000  0.011734
# daily        0.014993  0.002714  0.012280
# transport    0.028031  0.014925  0.013106
# must         0.014993  0.001357  0.013637
# exactly      0.016949  0.002714  0.014235
# fantastic    0.017601  0.002714  0.014887
# thank        0.021512  0.005427  0.016085
# recommend    0.021512  0.005427  0.016085
# travel       0.020209  0.004071  0.016138
# denmark      0.018905  0.002714  0.016191
# helps        0.017601  0.001357  0.016244
# perfect      0.018253  0.001357  0.016896
# always       0.044980  0.027137  0.017843
# brilliant    0.023468  0.005427  0.018041
# amazing      0.020860  0.002714  0.018147
# works        0.048240  0.029851  0.018389
# handy        0.024120  0.001357  0.022763
# really       0.051499  0.028494  0.023005
# thanks       0.029987  0.006784  0.023203
# nice         0.026076  0.002714  0.023362
# london       0.034550  0.010855  0.023695
# better       0.064537  0.040706  0.023832
# than         0.060626  0.036635  0.023991
# well         0.041721  0.016282  0.025439
# official     0.033898  0.005427  0.028471
# reliable     0.047588  0.018996  0.028592
# dublin       0.073664  0.035278  0.038385
# helpful      0.044329  0.004071  0.040258
# love         0.049544  0.004071  0.045473
# excellent    0.048240  0.001357  0.046883
# best         0.069100  0.009498  0.059602
# use          0.147979  0.085482  0.062497
# useful       0.078227  0.008141  0.070086
# accurate     0.101043  0.027137  0.073906
# easy         0.085398  0.002714  0.082684
# good         0.115385  0.028494  0.086891
# great        0.183833  0.033921  0.149912
# very         0.234029  0.061058  0.172970

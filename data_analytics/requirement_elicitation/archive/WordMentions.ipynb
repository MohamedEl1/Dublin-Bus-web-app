# %% [markdown]
# <h3>1) Import Data</h3>

# %%
import pandas as pd
import string
import glob

path = r'data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    print(filename)
    df = pd.read_csv(filename, index_col=0, header=0)
    file_id=filename.split(".")[0].split("\\")[1]
    df["source"]=file_id
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# data\amsterdamGVB.csv
# data\amsterdamOVinfo.csv
# data\barcelonaBus.csv
# data\barcelonaTMB.csv
# data\copenhagenRejseplanen.csv
# data\dublinBus.csv
# data\dublinNextBus.csv
# data\dublinRTI.csv
# data\lisbonCarris.csv
# data\LondonMapWay.csv
# data\LondonUrbanThings.csv
# data\madridBus.csv
# data\madridJSVM.csv

# %%
df.shape
# Out:
# (7468, 6)

# %% [markdown]
# <h3>2) Remove Punctuation</h3>

# %%
reviews=[]
for review in df.review:
    reviews.append(review.translate(str.maketrans("","", string.punctuation)))
df["review"]=reviews

# %%
df.head()
# Out:
#             name  rating                date  upvotes  \
# 0  A Google user       3  September 30, 2018       20
# 1   Ozgur Kalkan       3   November 19, 2018        4
# 2      gabs igab       5    November 7, 2019        2
# 3         Damian       5       March 1, 2020        1
# 4        Pel Pan       1      March 28, 2019        1
#
#                                               review        source
# 0  Confusing for tourists with tourist tickets th...  amsterdamGVB
# 1  Its a good app more like an essential one but ...  amsterdamGVB
# 2  Excellent app I have used it on our visit to A...  amsterdamGVB
# 3  It works very well for traveling I use it ever...  amsterdamGVB
# 4   very bad accuracy and often not the shortest way  amsterdamGVB

# %%
df.shape
# Out:
# (7468, 6)

# %% [markdown]
# <h3>3) Add review length and remove short reviews</h3>

# %%
review_length=[]
for review in df.review:
    review_length.append(len(review.split()))

# %%
df["review_length"]=pd.Series(review_length)

# %%
df=df[df.review_length>=10]

# %%
df.shape
# Out:
# (1863, 7)

# %% [markdown]
# <h3>4) Filter by good (5*) and bad (1*) experiences</h3>

# %%
df_five=df[df.rating==5]

# %%
five_length=df_five.review_length.sum()
five_length
# Out:
# 14656

# %%
df_one=df[df.rating==1]

# %%
one_length=df_one.review_length.sum()
one_length
# Out:
# 15965

# %% [markdown]
# <h3>5) Extract frequently used words and calculate mentions per comment</h3>

# %%
counts_five=pd.Series(' '.join(df_five['review']).lower().split()).value_counts()

# %%
word_freq={}
for word in counts_five.index:
    word_freq[word]=[counts_five[word]/five_length*1000,0]

# %%
counts_one=pd.Series(' '.join(df_one['review']).lower().split()).value_counts()

# %%
for word in counts_one.index:
    freq=counts_one[word]/one_length*1000
    if word not in word_freq:
        word_freq[word]=[0,freq]
    else:
        word_freq[word][1]=freq

# %% [markdown]
# <h3>5) Insert data into Dataframe and calculate delta</h3>

# %%
mentions=pd.DataFrame.from_dict(word_freq,orient='index',columns=['good','bad'])

# %%
mentions['delta']=mentions.good-mentions.bad

# %%
sorted_mentions=mentions.sort_values(by='delta')

# %%
sorted_mentions[:50]
# Out:
#                  good        bad     delta
# not          3.548035   8.518635 -4.970600
# was          1.569323   5.073598 -3.504275
# at           3.479803   6.514250 -3.034446
# doesnt       0.750546   3.319762 -2.569216
# no           3.002183   5.512058 -2.509874
# useless      0.000000   2.317570 -2.317570
# just         2.046943   4.259317 -2.212374
# the         39.710699  41.778891 -2.068193
# that         4.844432   6.890072 -2.045640
# ads          0.409389   2.380207 -1.970818
# ikke         0.409389   2.317570 -1.908181
# update       1.091703   2.881303 -1.789600
# they         0.955240   2.693392 -1.738152
# times        3.275109   5.010961 -1.735852
# why          0.136463   1.816474 -1.680011
# cant         0.614083   2.254933 -1.640850
# show         0.341157   1.816474 -1.475316
# there        1.569323   3.006577 -1.437254
# now          2.456332   3.820858 -1.364526
# do           1.091703   2.380207 -1.288504
# a           18.217795  19.480113 -1.262318
# crashes      0.000000   1.190103 -1.190103
# another      0.204694   1.378014 -1.173320
# due          1.159934   2.317570 -1.157635
# same         0.272926   1.378014 -1.105089
# worst        0.000000   1.064829 -1.064829
# location     0.682314   1.691199 -1.008885
# cannot       0.000000   1.002192 -1.002192
# minutes      1.091703   2.067022 -0.975319
# 2            0.477620   1.440651 -0.963031
# full         0.068231   1.002192 -0.933961
# work         2.046943   2.943940 -0.896997
# try          0.000000   0.876918 -0.876918
# der          0.068231   0.939555 -0.871324
# completely   0.136463   1.002192 -0.865729
# until        0.136463   1.002192 -0.865729
# actually     0.136463   1.002192 -0.865729
# annoying     0.272926   1.127466 -0.854541
# wrong        0.341157   1.190103 -0.848946
# want         0.682314   1.503288 -0.820974
# não          0.000000   0.814281 -0.814281
# min          0.068231   0.876918 -0.808687
# hour         0.068231   0.876918 -0.808687
# before       0.887009   1.691199 -0.804191
# ad           0.136463   0.939555 -0.803092
# terrible     0.204694   1.002192 -0.797498
# then         1.091703   1.879111 -0.787407
# mins         0.341157   1.127466 -0.786309
# again        0.545852   1.315377 -0.769526
# check        0.614083   1.378014 -0.763931

# %%
sorted_mentions[-50:]
# Out:
#                 good        bad     delta
# stops       3.548035   2.505481  1.042554
# stop        4.503275   3.445036  1.058239
# around      1.569323   0.501096  1.068227
# with        4.980895   3.883495  1.097400
# nice        1.228166   0.125274  1.102892
# always      2.046943   0.939555  1.107388
# travel      1.296397   0.187911  1.108486
# recommend   1.364629   0.250548  1.114081
# one         4.093886   2.943940  1.149947
# handy       1.296397   0.062637  1.233760
# what        3.070415   1.816474  1.253941
# helpful     1.501092   0.187911  1.313181
# thank       1.569323   0.250548  1.318775
# would       3.206878   1.879111  1.327767
# be          5.594978   4.134043  1.460935
# much        2.456332   0.939555  1.516777
# you        10.917031   9.395553  1.521478
# works       2.797489   1.252740  1.544749
# using       2.797489   1.252740  1.544749
# reliable    2.183406   0.626370  1.557036
# this       14.737991  13.091137  1.646854
# really      2.865721   1.190103  1.675617
# well        2.456332   0.751644  1.704688
# my          6.550218   4.823050  1.727168
# london      2.183406   0.438459  1.744947
# transport   2.524563   0.689007  1.835556
# thanks      2.183406   0.313185  1.870221
# official    2.251638   0.250548  2.001089
# excellent   2.046943   0.000000  2.046943
# than        3.684498   1.628562  2.055935
# best        2.592795   0.438459  2.154336
# better      3.889192   1.691199  2.197993
# to         30.021834  27.622925  2.398909
# i          23.335153  20.920764  2.414389
# can         4.707969   2.192296  2.515674
# for        13.919214  11.337300  2.581914
# accurate    3.820961   1.190103  2.630857
# love        2.933952   0.125274  2.808678
# useful      3.411572   0.375822  3.035750
# its         7.300764   4.196680  3.104084
# easy        3.957424   0.125274  3.832150
# is         17.808406  13.968055  3.840351
# dublin      5.867904   1.565925  4.301978
# and        25.586790  20.858127  4.728663
# good        6.209061   1.190103  5.018958
# use         9.006550   3.445036  5.561514
# bus        24.426856  17.225180  7.201676
# very       11.121725   2.380207  8.741518
# app        32.819323  23.426245  9.393078
# great      10.848799   1.378014  9.470785

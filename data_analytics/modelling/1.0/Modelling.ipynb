# %%
import pandas as pd
import os, sys
import numpy as np

# %%
def clean_stops(df, verbose=False):
    """
    Iterates through all series associated with each progrnum and stop_id, finds the id of stops which appear less frequently. Then finds the indexes of rows with the progrnum and these stops.
    Makes note of all these indexes and then removes them all.
    """
    indexes_to_be_removed = []
    for i in range(1,max(df['progrnum'])+1):
        series = df[df['progrnum'] == i]['stop_id'].value_counts()
        if verbose:
            print(series)
        stops_to_be_removed = series.index.tolist()[1:]
        if verbose:
            print("Checking progrnum: ",i," inconsistent stops are: ",stops_to_be_removed)
        if len(stops_to_be_removed) > 0:
            indexes_to_be_removed += list(df[df['progrnum'] == i][df['stop_id'].isin(stops_to_be_removed)].index)
    if verbose:
        print("Removing ",len(indexes_to_be_removed), " rows")
    df.drop(df.index[indexes_to_be_removed], inplace=True)

# %%
from scipy import stats
def clean_outliers(df, verbose=False):
    """
    Iterates through all series associated with each progrnum and cum_duration, finds the indexs of those rows with values more than 3 standard deviations from the mean.
    Makes note of all these indexes and then removes them all
    """
    indexes_to_be_removed = []
    for i in range(1,max(df['progrnum'])+1):
        series = df[df['progrnum'] == i]['cum_duration']
        indexes_to_be_removed += list(series[((np.abs(stats.zscore(series)) > 3))].index)
    if verbose:
        print("Removing ",len(indexes_to_be_removed), " rows")
    df.drop(indexes_to_be_removed, inplace=True)

# %%
def test_of_removing(route_id, verbose=False, outliers_verbose=False):
    if verbose:
        print("="*20)
        print(route_id)
    df = pd.read_csv('D:\\data\\csvs\\csvs\\' + str(route_id) + '_1.csv')
    df = df.drop(columns=['dt','Unnamed: 0','tripid','weather_main'])
    len_before = len(df)
    clean_stops(df)
    clean_outliers(df, outliers_verbose)
    len_after = len(df)
    if verbose:
        print("Total rows removed: ", len_before-len_after)
        print("Percentage of rows removed: ", (len_before-len_after)*100/len_before,"%")
        print("="*20)
    return (len_before-len_after)*100/len_before

# %%
from tqdm import tqdm_notebook as tqdm
route_ids = ['68', '25B', '45A', '25A', '14', '77A', '39', '16', '40D', '27B', '142', '83', '130', '15', '46A', '33', '7', '39A', '49', '1', '123', '41', '67X', '59', '9', '40', '239', '76', '84', '53', '185', '151', '13', '15B', '65B', '29A', '61', '140', '79A', '38A', '31', '33B', '69', '44', '42', '67', '184', '238', '145', '17A', '32', '27A', '17', '27X', '18', '122', '54A', '66', '150', '56A', '37', '27', '15A', '65', '11', '47', '79', '83A', '63', '4', '120', '41C', '70', '84A', '220', '39X', '32X', '68A', '84X', '38', '102', '270', '51X', '33X', '75', '26', '66A', '31A', '111', '14C', '114', '76A', '44B', '161', '7A', '43', '25', '104', '33A', '16C', '42D', '31B', '66X', '31D', '33D', '41B', '40B', '7D', '46E', '38D', '118', '51D', '15D', '41A', '25D', '66B', '38B', '236', '7B', '41X', '69X', '68X', '25X', '40E', '70D', '116', '77X', '16D', '33E', '41D']
routes_to_check = []
for route in tqdm(route_ids):
    try:
        percent = test_of_removing(route)
        if percent > 3:
            routes_to_check.append(route)
    except Exception as e:
        print(e)
print(routes_to_check)
# Out:
# HBox(children=(IntProgress(value=0, max=130), HTML(value='')))
# C:\Users\callu_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# C:\Users\callu_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in greater
#   # Remove the CWD from sys.path while we load stuff.
# [Errno 2] File b'D:\\data\\csvs\\csvs\\51X_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\51X_1.csv'
# [Errno 2] File b'D:\\data\\csvs\\csvs\\46E_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\46E_1.csv'
# [Errno 2] File b'D:\\data\\csvs\\csvs\\118_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\118_1.csv'
# [Errno 2] File b'D:\\data\\csvs\\csvs\\41A_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\41A_1.csv'
# [Errno 2] File b'D:\\data\\csvs\\csvs\\68X_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\68X_1.csv'
# [Errno 2] File b'D:\\data\\csvs\\csvs\\77X_1.csv' does not exist: b'D:\\data\\csvs\\csvs\\77X_1.csv'
# ['68', '16', '40D', '142', '83', '15', '33', '41', '67X', '59', '84', '13', '33B', '17A', '17', '27X', '47', '4', '84A', '220', '84X', '38', '33X', '75', '114', '7A', '104', '42D', '66X', '33D', '236', '41X', '25X']

# %%
from tqdm import tqdm_notebook as tqdm
for route in tqdm(routes_to_check):
    percent = test_of_removing(route, verbose=True, outliers_verbose=True)
# Out:
# HBox(children=(IntProgress(value=0, max=33), HTML(value='')))
# ====================
# 68
# C:\Users\callu_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# Removing  2897  rows
# Total rows removed:  25287
# Percentage of rows removed:  6.965616787778286 %
# ====================
# ====================
# 16
# Removing  6401  rows
# Total rows removed:  175666
# Percentage of rows removed:  12.548073351505488 %
# ====================
# ====================
# 40D
# Removing  3945  rows
# Total rows removed:  50094
# Percentage of rows removed:  8.775980715056551 %
# ====================
# ====================
# 142
# Removing  421  rows
# Total rows removed:  4743
# Percentage of rows removed:  11.60281814178776 %
# ====================
# ====================
# 83
# Removing  12075  rows
# Total rows removed:  93738
# Percentage of rows removed:  9.367561204237978 %
# ====================
# ====================
# 15
# Removing  12981  rows
# Total rows removed:  205032
# Percentage of rows removed:  11.54197555397058 %
# ====================
# ====================
# 33
# Removing  7710  rows
# Total rows removed:  24129
# Percentage of rows removed:  6.595488203891855 %
# ====================
# ====================
# 41
# Removing  4657  rows
# Total rows removed:  29659
# Percentage of rows removed:  4.074850073160176 %
# ====================
# ====================
# 67X
# Removing  731  rows
# Total rows removed:  11600
# Percentage of rows removed:  16.228088582980092 %
# ====================
# ====================
# 59
# Removing  312  rows
# Total rows removed:  7175
# Percentage of rows removed:  7.799676055266276 %
# ====================
# ====================
# 84
# Removing  3852  rows
# Total rows removed:  158189
# Percentage of rows removed:  36.10228017043652 %
# ====================
# ====================
# 13
# Removing  6789  rows
# Total rows removed:  689370
# Percentage of rows removed:  46.762565527421124 %
# ====================
# ====================
# 33B
# Removing  1212  rows
# Total rows removed:  4756
# Percentage of rows removed:  3.9388142148459173 %
# ====================
# ====================
# 17A
# Removing  6306  rows
# Total rows removed:  47796
# Percentage of rows removed:  5.56524574129921 %
# ====================
# ====================
# 17
# Removing  4508  rows
# Total rows removed:  49564
# Percentage of rows removed:  9.874290267954976 %
# ====================
# ====================
# 27X
# Removing  237  rows
# Total rows removed:  1131
# Percentage of rows removed:  5.88572023313905 %
# ====================
# ====================
# 47
# Removing  2611  rows
# Total rows removed:  39452
# Percentage of rows removed:  17.935580660559634 %
# ====================
# ====================
# 4
# Removing  6870  rows
# Total rows removed:  80538
# Percentage of rows removed:  8.542943304803112 %
# ====================
# ====================
# 84A
# Removing  75  rows
# Total rows removed:  1182
# Percentage of rows removed:  16.75170068027211 %
# ====================
# ====================
# 220
# Removing  1697  rows
# Total rows removed:  7276
# Percentage of rows removed:  3.3751124882873023 %
# ====================
# ====================
# 84X
# Removing  945  rows
# Total rows removed:  7682
# Percentage of rows removed:  14.263963161021984 %
# ====================
# ====================
# 38
# Removing  3331  rows
# Total rows removed:  24543
# Percentage of rows removed:  5.837344927315625 %
# ====================
# ====================
# 33X
# Removing  319  rows
# Total rows removed:  23233
# Percentage of rows removed:  38.32816418107431 %
# ====================
# ====================
# 75
# Removing  191  rows
# Total rows removed:  34778
# Percentage of rows removed:  41.65129703705478 %
# ====================
# ====================
# 114
# Removing  2078  rows
# Total rows removed:  31977
# Percentage of rows removed:  24.572363871086726 %
# ====================
# ====================
# 7A
# Removing  3004  rows
# Total rows removed:  35261
# Percentage of rows removed:  5.233194072381066 %
# ====================
# ====================
# 104
# Removing  1078  rows
# Total rows removed:  8130
# Percentage of rows removed:  6.577137772024917 %
# ====================
# ====================
# 42D
# Removing  108  rows
# Total rows removed:  149
# Percentage of rows removed:  3.1803628601921026 %
# ====================
# ====================
# 66X
# Removing  348  rows
# Total rows removed:  3604
# Percentage of rows removed:  10.975089834947317 %
# ====================
# ====================
# 33D
# Removing  104  rows
# Total rows removed:  148
# Percentage of rows removed:  3.6926147704590817 %
# ====================
# ====================
# 236
# Removing  100  rows
# Total rows removed:  448
# Percentage of rows removed:  3.028664142779881 %
# ====================
# ====================
# 41X
# Removing  154  rows
# Total rows removed:  4086
# Percentage of rows removed:  18.678857142857144 %
# ====================
# ====================
# 25X
# Removing  222  rows
# Total rows removed:  1856
# Percentage of rows removed:  10.113890251212467 %
# ====================

# %%
df = pd.read_csv('D:\\data\\csvs\\csvs\\' + '75' + '_1.csv')
df = df.drop(columns=['dt','Unnamed: 0','tripid','weather_main'])
print(len(df))
clean_stops(df, verbose=True)
clean_outliers(df, True)
# Out:
# 83498
# 4348.0    954
# 4646.0      4
# 2538.0      2
# Name: stop_id, dtype: int64
# Checking progrnum:  1  inconsistent stops are:  [4646.0, 2538.0]
# C:\Users\callu_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# 4646.0    960
# Name: stop_id, dtype: int64
# Checking progrnum:  2  inconsistent stops are:  []
# 4647.0    965
# Name: stop_id, dtype: int64
# Checking progrnum:  3  inconsistent stops are:  []
# 4435.0    961
# 2538.0      4
# Name: stop_id, dtype: int64
# Checking progrnum:  4  inconsistent stops are:  [2538.0]
# 2605.0    539
# 2604.0    423
# Name: stop_id, dtype: int64
# Checking progrnum:  5  inconsistent stops are:  [2604.0]
# 2538.0    539
# 2605.0    423
# Name: stop_id, dtype: int64
# Checking progrnum:  6  inconsistent stops are:  [2605.0]
# 2539.0    544
# 2538.0    423
# Name: stop_id, dtype: int64
# Checking progrnum:  7  inconsistent stops are:  [2538.0]
# 2540.0    544
# 2539.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  8  inconsistent stops are:  [2539.0]
# 2542.0    544
# 2540.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  9  inconsistent stops are:  [2540.0]
# 6128.0    544
# 2542.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  10  inconsistent stops are:  [2542.0]
# 2544.0    544
# 6128.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  11  inconsistent stops are:  [6128.0]
# 2545.0    623
# 2544.0    345
# Name: stop_id, dtype: int64
# Checking progrnum:  12  inconsistent stops are:  [2544.0]
# 2547.0    544
# 2545.0    345
# Name: stop_id, dtype: int64
# Checking progrnum:  13  inconsistent stops are:  [2545.0]
# 2548.0    547
# 2547.0    421
# Name: stop_id, dtype: int64
# Checking progrnum:  14  inconsistent stops are:  [2547.0]
# 946.0     544
# 2548.0    421
# Name: stop_id, dtype: int64
# Checking progrnum:  15  inconsistent stops are:  [2548.0]
# 1131.0    544
# 946.0     424
# Name: stop_id, dtype: int64
# Checking progrnum:  16  inconsistent stops are:  [946.0]
# 1132.0    544
# 1131.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  17  inconsistent stops are:  [1131.0]
# 1133.0    544
# 1132.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  18  inconsistent stops are:  [1132.0]
# 1134.0    544
# 1133.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  19  inconsistent stops are:  [1133.0]
# 5131.0    544
# 1134.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  20  inconsistent stops are:  [1134.0]
# 5132.0    544
# 5131.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  21  inconsistent stops are:  [5131.0]
# 1305.0    544
# 5132.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  22  inconsistent stops are:  [5132.0]
# 1306.0    544
# 1305.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  23  inconsistent stops are:  [1305.0]
# 1307.0    544
# 1306.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  24  inconsistent stops are:  [1306.0]
# 1308.0    544
# 1307.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  25  inconsistent stops are:  [1307.0]
# 1309.0    544
# 1308.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  26  inconsistent stops are:  [1308.0]
# 4332.0    544
# 1309.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  27  inconsistent stops are:  [1309.0]
# 4333.0    544
# 4332.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  28  inconsistent stops are:  [4332.0]
# 4334.0    544
# 4333.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  29  inconsistent stops are:  [4333.0]
# 4712.0    544
# 4334.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  30  inconsistent stops are:  [4334.0]
# 2853.0    544
# 4712.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  31  inconsistent stops are:  [4712.0]
# 2854.0    544
# 2853.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  32  inconsistent stops are:  [2853.0]
# 2855.0    544
# 2854.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  33  inconsistent stops are:  [2854.0]
# 2856.0    544
# 2855.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  34  inconsistent stops are:  [2855.0]
# 2857.0    544
# 2856.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  35  inconsistent stops are:  [2856.0]
# 2858.0    544
# 2857.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  36  inconsistent stops are:  [2857.0]
# 2859.0    544
# 2858.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  37  inconsistent stops are:  [2858.0]
# 2860.0    544
# 2859.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  38  inconsistent stops are:  [2859.0]
# 2861.0    544
# 2860.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  39  inconsistent stops are:  [2860.0]
# 2862.0    544
# 2861.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  40  inconsistent stops are:  [2861.0]
# 2863.0    544
# 2862.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  41  inconsistent stops are:  [2862.0]
# 2864.0    544
# 2863.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  42  inconsistent stops are:  [2863.0]
# 4486.0    544
# 2864.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  43  inconsistent stops are:  [2864.0]
# 4586.0    544
# 4486.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  44  inconsistent stops are:  [4486.0]
# 2872.0    544
# 4586.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  45  inconsistent stops are:  [4586.0]
# 2873.0    544
# 2872.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  46  inconsistent stops are:  [2872.0]
# 2874.0    544
# 2873.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  47  inconsistent stops are:  [2873.0]
# 2877.0    541
# 2874.0    424
# 7394.0      2
# 2879.0      1
# Name: stop_id, dtype: int64
# Checking progrnum:  48  inconsistent stops are:  [2874.0, 7394.0, 2879.0]
# 7394.0    541
# 2877.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  49  inconsistent stops are:  [2877.0]
# 2878.0    543
# 7394.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  50  inconsistent stops are:  [7394.0]
# 2879.0    543
# 2878.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  51  inconsistent stops are:  [2878.0]
# 4779.0    544
# 2879.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  52  inconsistent stops are:  [2879.0]
# 7057.0    544
# 4779.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  53  inconsistent stops are:  [4779.0]
# 4847.0    544
# 7057.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  54  inconsistent stops are:  [7057.0]
# 4848.0    544
# 4847.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  55  inconsistent stops are:  [4847.0]
# 449.0     535
# 4848.0    424
# 450.0       9
# Name: stop_id, dtype: int64
# Checking progrnum:  56  inconsistent stops are:  [4848.0, 450.0]
# 450.0    553
# 449.0    406
# Name: stop_id, dtype: int64
# Checking progrnum:  57  inconsistent stops are:  [449.0]
# 3181.0    543
# 450.0     406
# 5045.0      1
# Name: stop_id, dtype: int64
# Checking progrnum:  58  inconsistent stops are:  [450.0, 5045.0]
# 447.0     543
# 3181.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  59  inconsistent stops are:  [3181.0]
# 5045.0    543
# 447.0     424
# Name: stop_id, dtype: int64
# Checking progrnum:  60  inconsistent stops are:  [447.0]
# 4460.0    544
# 5045.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  61  inconsistent stops are:  [5045.0]
# 453.0     544
# 4460.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  62  inconsistent stops are:  [4460.0]
# 4477.0    544
# 453.0     424
# Name: stop_id, dtype: int64
# Checking progrnum:  63  inconsistent stops are:  [453.0]
# 3321.0    544
# 4477.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  64  inconsistent stops are:  [4477.0]
# 4571.0    544
# 3321.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  65  inconsistent stops are:  [3321.0]
# 2013.0    544
# 4571.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  66  inconsistent stops are:  [4571.0]
# 2014.0    544
# 2013.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  67  inconsistent stops are:  [2013.0]
# 4636.0    544
# 2014.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  68  inconsistent stops are:  [2014.0]
# 2016.0    544
# 4636.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  69  inconsistent stops are:  [4636.0]
# 2015.0    544
# 2016.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  70  inconsistent stops are:  [2016.0]
# 2017.0    544
# 2015.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  71  inconsistent stops are:  [2015.0]
# 2018.0    544
# 2017.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  72  inconsistent stops are:  [2017.0]
# 2019.0    544
# 2018.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  73  inconsistent stops are:  [2018.0]
# 2020.0    544
# 2019.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  74  inconsistent stops are:  [2019.0]
# 2021.0    544
# 2020.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  75  inconsistent stops are:  [2020.0]
# 2022.0    544
# 2021.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  76  inconsistent stops are:  [2021.0]
# 4565.0    544
# 2022.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  77  inconsistent stops are:  [2022.0]
# 4566.0    544
# 4565.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  78  inconsistent stops are:  [4565.0]
# 4567.0    544
# 4566.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  79  inconsistent stops are:  [4566.0]
# 2031.0    543
# 4567.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  80  inconsistent stops are:  [4567.0]
# 2032.0    542
# 2031.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  81  inconsistent stops are:  [2031.0]
# 2033.0    542
# 2032.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  82  inconsistent stops are:  [2032.0]
# 2034.0    542
# 2033.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  83  inconsistent stops are:  [2033.0]
# 2035.0    541
# 2034.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  84  inconsistent stops are:  [2034.0]
# 2036.0    540
# 2035.0    424
# Name: stop_id, dtype: int64
# Checking progrnum:  85  inconsistent stops are:  [2035.0]
# 2038.0    539
# 2036.0    423
# Name: stop_id, dtype: int64
# Checking progrnum:  86  inconsistent stops are:  [2036.0]
# 2038.0    421
# Name: stop_id, dtype: int64
# Checking progrnum:  87  inconsistent stops are:  []
# Removing  34587  rows
# Removing  191  rows
